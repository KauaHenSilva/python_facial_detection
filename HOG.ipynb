# %% [markdown]
# <a href="https://colab.research.google.com/github/KauaHenSilva/python_facial_detection/blob/main/HOG.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Importação das bibliotecas e setup

# %%
from google.colab.drive import mount
from google.colab.patches import cv2_imshow
import cv2
import dlib

# %%
# drive: https://drive.google.com/drive/folders/1OXTbhGlG6Y-x6hMY_5Y8Ed3mPB9lP5LF?usp=sharing
mount("/content/drive")
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Detecção de faces com HOG+SVM (DLIB)

# %%
def exibir_detections(detecctions, img_dec):
  for face in detecctions:
      top, left, right, bottom = face.top(), face.left(), face.right(), face.bottom()
      cv2.rectangle(img_dec, (left, top),(right, bottom), (0, 255, 0), 2)
  cv2_imshow(img_dec)

# %%
img = cv2.imread("/content/drive/MyDrive/Face Detection and Recognition/images/people1.jpg")
img = cv2.resize(img, (0,0), fx=0.5, fy=0.5)
face_detection = dlib.get_frontal_face_detector()
detecctions = face_detection(img)
exibir_detections(detecctions, img)
# Out:
# <PIL.Image.Image image mode=RGB size=840x560>

# %%
img = cv2.imread("/content/drive/MyDrive/Face Detection and Recognition/images/people2.jpg")
face_detection = dlib.get_frontal_face_detector()
detecctions = face_detection(img)
exibir_detections(detecctions, img)
# Out:
# <PIL.Image.Image image mode=RGB size=600x500>

# %% [markdown]
# ## Parametro Upsampling

# %%
img = cv2.imread("/content/drive/MyDrive/Face Detection and Recognition/images/people3.jpg")
face_detection = dlib.get_frontal_face_detector()
detecctions = face_detection(img, 3)
exibir_detections(detecctions, img)
# Out:
# <PIL.Image.Image image mode=RGB size=612x408>

# %%
img = cv2.imread("/content/drive/MyDrive/Face Detection and Recognition/images/people5.jpg")
face_detection = dlib.get_frontal_face_detector()
detecctions = face_detection(img, 2)
exibir_detections(detecctions, img)
# Out:
# <PIL.Image.Image image mode=RGB size=700x519>
